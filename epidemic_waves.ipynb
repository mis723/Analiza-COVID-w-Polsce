# %%
# %%time

# %run dataframes.ipynb
# Out:
# Wall time: 4min 35s

# %%
# %run funkcje.ipynb
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 17})

# %%
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
which_district = "leszno"
cond = infections.district == which_district

print_full(infections.loc[cond, ["infected_total", "date"]])
# Out:
# Empty DataFrame
# Columns: [infected_total, date]
# Index: []

# %%
#Ilość nowych przypadków per capita w czasie dla wybranego powiatu

#              date      district
# 5935   2020-12-24       kłodzki
# 12279  2020-12-23    polkowicki
# 39115  2020-12-23   biłgorajski
# 52508  2020-12-21      łukowski
# 57444  2020-12-22    nowosolski
# 85240  2020-12-21  sochaczewski
# 104275 2020-12-21   proszowicki
# 107094 2020-12-20    tatrzański
# 117571 2020-12-23    brzozowski
# 123010 2020-12-24      mielecki
# 133181 2020-12-23   białostocki
# 254440 2020-12-22      żywiecki

plt.rcParams.update({'font.size': 23})

which_district = "piaseczyński"
#which_province = "małopolskie"
fig, ax = plt.subplots()

district_cond = (infections.district == which_district)
# district_cond = (infections.district == which_district) & (infections.province == which_province)
x = infections[district_cond]["date"]
y = infections[district_cond]["new_infected_mean"]
# / infections[district_cond]["population"]
x2 = infections[(district_cond) & (infections.scnd_wave_day == 0)]["date"]
y2 = 0
plt.plot_date(x, y, 'ro', markersize = 3)
plt.plot_date(x2, y2, "g|", markersize = 65)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Liczba zakażeń (wygładzone)')
plt.xlim([np.datetime64('2020-05-03'), np.datetime64('2021-12-20')])

np.datetime64('2005-02-25')
#plt.ylim([0, 350])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 1:
        label.set_visible(False)
#plt.title(which_district)
plt.title('Powiat piaseczyński')

plt.savefig("piaseczno_2fala.pdf")

# %%
#Ilość nowych przypadków per capita w czasie dla wybranego powiatu

#              date      district
# 5935   2020-12-24       kłodzki
# 12279  2020-12-23    polkowicki
# 39115  2020-12-23   biłgorajski
# 52508  2020-12-21      łukowski
# 57444  2020-12-22    nowosolski
# 85240  2020-12-21  sochaczewski
# 104275 2020-12-21   proszowicki
# 107094 2020-12-20    tatrzański
# 117571 2020-12-23    brzozowski
# 123010 2020-12-24      mielecki
# 133181 2020-12-23   białostocki
# 254440 2020-12-22      żywiecki

plt.rcParams.update({'font.size': 23})

which_district = "nowosolski"
#which_province = "małopolskie"
fig, ax = plt.subplots()

district_cond = (infections.district == which_district)
# district_cond = (infections.district == which_district) & (infections.province == which_province)
x = infections[district_cond]["date"]
y = infections[district_cond]["new_infected_mean"]
# / infections[district_cond]["population"]
x2 = infections[(district_cond) & (infections.scnd_wave_day == 0)]["date"]
y2 = 0
plt.plot_date(x, y, 'ro', markersize = 3)
plt.plot_date(x2, y2, "g|", markersize = 77)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Liczba zakażeń (wygładzone)')
plt.xlim([np.datetime64('2020-05-03'), np.datetime64('2021-12-20')])

np.datetime64('2005-02-25')
plt.ylim([0, 110])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 1:
        label.set_visible(False)
#plt.title(which_district)
plt.title('Powiat nowosolski')
print(x2)

plt.savefig("nowosolski_2fala.pdf")
# Out:
# 57444   2020-12-22
# Name: date, dtype: datetime64[ns]

# %%
#Ilość nowych śmierci per capita w czasie dla wybranego powiatu

#              date      district
# 5935   2020-12-24       kłodzki
# 12279  2020-12-23    polkowicki
# 39115  2020-12-23   biłgorajski
# 52508  2020-12-21      łukowski
# 57444  2020-12-22    nowosolski
# 85240  2020-12-21  sochaczewski
# 104275 2020-12-21   proszowicki
# 107094 2020-12-20    tatrzański
# 117571 2020-12-23    brzozowski
# 123010 2020-12-24      mielecki
# 133181 2020-12-23   białostocki
# 254440 2020-12-22      żywiecki

which_district = "białobrzeski"
#which_province = "małopolskie"
fig, ax = plt.subplots()

district_cond = (deaths.district == which_district)
# district_cond = (infections.district == which_district) & (infections.province == which_province)

print(deaths[district_cond])
x = deaths[district_cond]["date"]
y = deaths[district_cond]["new_death_mean"] / deaths[district_cond]["population"]
x2 = deaths[(district_cond) & (deaths.scnd_wave_day == 0)]["date"]
y2 = 0
plt.plot_date(x, y, 'bo', markersize = 3)
plt.plot_date(x2, y2, "r|", markersize = 50)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Liczba śmierci per capita (wygładzone)')
#plt.ylim([0, 0.003])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.title(which_district)

print(x2)
# Out:
#             date     province      district  dead_total  population  area_ha  \
# 65156 2020-03-04  mazowieckie  białobrzeski         0.0       33410    63910
# 65157 2020-03-05  mazowieckie  białobrzeski         0.0       33410    63910
# 65158 2020-03-06  mazowieckie  białobrzeski         0.0       33410    63910
# 65159 2020-03-07  mazowieckie  białobrzeski         0.0       33410    63910
# 65160 2020-03-08  mazowieckie  białobrzeski         0.0       33410    63910
# ...          ...          ...           ...         ...         ...      ...
# 65867 2022-02-13  mazowieckie  białobrzeski        49.0       33410    63910
# 65868 2022-02-14  mazowieckie  białobrzeski        49.0       33410    63910
# 65869 2022-02-15  mazowieckie  białobrzeski        49.0       33410    63910
# 65870 2022-02-16  mazowieckie  białobrzeski        49.0       33410    63910
# 65871 2022-02-17  mazowieckie  białobrzeski        49.0       33410    63910
#
# ...

# %%
print(infections)
# Out:
#              date        province       district  infected_total  population  \
# 0      2020-03-04    dolnośląskie  bolesławiecki             0.0       90103
# 1      2020-03-05    dolnośląskie  bolesławiecki             0.0       90103
# 2      2020-03-06    dolnośląskie  bolesławiecki             0.0       90103
# 3      2020-03-07    dolnośląskie  bolesławiecki             0.0       90103
# 4      2020-03-08    dolnośląskie  bolesławiecki             0.0       90103
# ...           ...             ...            ...             ...         ...
# 264314 2022-02-02  świętokrzyskie   włoszczowski          3561.0       45059
# 264315 2022-02-03  świętokrzyskie   włoszczowski          3589.0       45059
# 264316 2022-02-04  świętokrzyskie   włoszczowski          3626.0       45059
# 264317 2022-02-05  świętokrzyskie   włoszczowski          3648.0       45059
# 264318 2022-02-06  świętokrzyskie   włoszczowski          3663.0       45059
#
# ...

# %%
# średnia data rozpoczęcia 2. fali
countries_to_keep = ['bieszczadzki', 'kazimierski', 'kolbuszowski', 'krosno', 'leski', 'leżajski', 'namysłowski', 'ostrołęka', 'tarnobrzeski', 'sokólski']
countries_to_keep_deaths = ['bieszczadzki', 'kazimierski', 'kolbuszowski', 'krosno', 'leski', 'leżajski', 'namysłowski', 'ostrołęka', 'tarnobrzeski', 'sokólski', 'giżycki']

infections_fix = infections[~infections.district.isin(countries_to_keep)]
deaths_fix = deaths[~deaths.district.isin(countries_to_keep_deaths)]
wave2_dates = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20"), 'date']
day_02_date_mean = (np.array(wave2_dates, dtype='datetime64[D]')
        .view('i8')
        .mean()
        .astype('datetime64[D]'))

print(day_02_date_mean)
#print(day_02_date_mean_death)
# Out:
# 2021-01-31

# %%
countries_to_keep = ['bieszczadzki', 'kazimierski', 'kolbuszowski', 'krosno', 'leski', 'leżajski', 'namysłowski', 'ostrołęka', 'tarnobrzeski', 'sokólski']
for el in countries_to_keep:
    print(infections.loc[(infections.district == el), 'date'])
# Out:
# 116975   2020-03-04
# 116976   2020-03-05
# 116977   2020-03-06
# 116978   2020-03-07
# 116979   2020-03-08
#             ...
# 117272   2020-12-26
# 117273   2020-12-27
# 117274   2020-12-28
# 117275   2020-12-29
# 117276   2020-12-30
# Name: date, Length: 302, dtype: datetime64[ns]
# 256262   2020-03-04
# 256263   2020-03-05
# 256264   2020-03-06
# 256265   2020-03-07
# 256266   2020-03-08
#             ...
# 256559   2020-12-26
# 256560   2020-12-27
# 256561   2020-12-28
# 256562   2020-12-29
# 256563   2020-12-30
# Name: date, Length: 302, dtype: datetime64[ns]
# 120097   2020-03-04
# 120098   2020-03-05
# 120099   2020-03-06
# 120100   2020-03-07
# 120101   2020-03-08
#             ...
# 120394   2020-12-26
# 120395   2020-12-27
# 120396   2020-12-28
# 120397   2020-12-29
# 120398   2020-12-30
# Name: date, Length: 302, dtype: datetime64[ns]
# 120399   2020-03-04
# 120400   2020-03-05
# 120401   2020-03-06
# 120402   2020-03-07
# 120403   2020-03-08
#             ...
# ...

# %%
removal = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20") & (infections_fix.date < "2021-01-05"), ('district', 'province')]
removal = removal.reset_index(drop=True)
print(len(removal))
print(removal)
infections_fix2 = infections_fix
for i in range (len(removal)):
    infections_fix2 = infections_fix2.loc[~((infections_fix2.district == removal.district[i]) & (infections_fix2.province == removal.province[i]))]
    
removal_death = deaths_fix.loc[(deaths_fix.scnd_wave_day == 0) & (deaths_fix.date > "2020-10-20") & (deaths_fix.date < "2021-01-05"), ('district', 'province')]
removal_death = removal_death.reset_index(drop=True)
print(removal_death)
deaths_fix2 = deaths_fix
for i in range (len(removal_death)):
    deaths_fix2 = deaths_fix2.loc[~((deaths_fix2.district == removal_death.district[i]) & (deaths_fix2.province == removal_death.province[i]))]
# Out:
# 29
#                district            province
# 0               kłodzki        dolnośląskie
# 1            polkowicki        dolnośląskie
# 2   golubsko-dobrzyński  kujawsko-pomorskie
# 3           biłgorajski           lubelskie
# 4           lubartowski           lubelskie
# 5           tomaszowski           lubelskie
# 6              łukowski           lubelskie
# 7            nowosolski            lubuskie
# 8               mławski         mazowieckie
# 9              pułtuski         mazowieckie
# 10         sochaczewski         mazowieckie
# 11         szydłowiecki         mazowieckie
# 12              olkuski         małopolskie
# 13          proszowicki         małopolskie
# 14            tarnowski         małopolskie
# 15           tatrzański         małopolskie
# 16           brzozowski        podkarpackie
# 17          krośnieński        podkarpackie
# 18             mielecki        podkarpackie
# 19              sanocki        podkarpackie
# ...

# %%
#histogram przez usunięciem ostatnich wcześniaków

infections_fix = infections[~infections.district.isin(countries_to_keep)]
wave2_dates = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20"), 'date']
day_02_date_mean = (np.array(wave2_dates, dtype='datetime64[D]')
        .view('i8')
        .mean()
        .astype('datetime64[D]'))

wave2_dates_fix = infections_fix2.loc[(infections_fix2.scnd_wave_day == 0) & (infections_fix2.date > "2020-10-20"), 'date']
day_02_date_mean_fix = (np.array(wave2_dates, dtype='datetime64[D]')
        .view('i8')
        .mean()
        .astype('datetime64[D]'))
print(day_02_date_mean_fix)

# wave2_dates_fix = infections_fix2.loc[(infections_fix2.scnd_wave_day == 0) & (infections_fix2.date > "2020-10-20"), 'date']
# day_02_date_mean_fix = (np.array(wave2_dates, dtype='datetime64[D]')
#         .view('i8')
#         .mean()
#         .astype('datetime64[D]'))
# print(day_02_date_mean_fix)

fig, ax = plt.subplots()
plt.title("Histogram daty rozpoczęcia 2. fali dla polskich powiatów")
wave2_dates.astype(np.int64).plot.hist(ax=ax, bins=15,alpha=0.7, rwidth=0.85, edgecolor='black')
tickies = np.linspace(start = 1.60862e+18, stop = 1.61435e+18, num = 15)
ax.set_xticks(tickies)
labels = ax.get_xticks().tolist()
labels = pd.to_datetime(labels).strftime('%d.%m.%Y')
ax.set_xticklabels(labels, rotation=90)
ax.set_ylabel("Liczba zliczeń")
x = day_02_date_mean_fix.astype(np.int64)*86402000000000  #manualnie ustawione na średnią datę 2021-01-31
y = 0
plt.plot_date(x, y, "r|", markersize = 900)

#plt.savefig('wave2_hist.eps', format='eps')
#plt.savefig("wave2_hist.pdf")
# Out:
# 2021-01-31

# %%
#histogram przez usunięciem ostatnich wcześniaków
plt.rcParams.update({'font.size': 20})
infections_fix = infections[~infections.district.isin(countries_to_keep)]
wave2_dates = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20"), 'date']
day_02_date_mean = (np.array(wave2_dates, dtype='datetime64[D]')
        .view('i8')
        .mean()
        .astype('datetime64[D]'))

wave2_dates_fix = infections_fix2.loc[(infections_fix2.scnd_wave_day == 0) & (infections_fix2.date > "2020-01-03"), 'date']
day_02_date_mean_fix = (np.array(wave2_dates_fix, dtype='datetime64[D]')
        .view('i8')
        .mean()
        .astype('datetime64[D]'))
print(day_02_date_mean_fix)

fig, ax = plt.subplots()
#plt.title("Histogram daty rozpoczęcia 2. fali dla polskich powiatów")
N, bins, patches = ax.hist(wave2_dates.astype(np.int64), bins=14,alpha=0.7, rwidth=0.9, edgecolor='black')
tickies = np.linspace(start = 1.60842240e+18, stop = 1.61455680e+18, num = 15)
# tickies = np.linspace(start = 1.60862e+18, stop = 1.61435e+18, num = 15)
ax.set_xticks(tickies)
labels = ax.get_xticks().tolist()
labels = pd.to_datetime(labels).strftime('%d.%m.%Y')
ax.set_xticklabels(labels, rotation=90)
ax.set_ylabel("Liczba powiatów w przedziale")
x = day_02_date_mean_fix.astype(np.int64)*86402900000000  #manualnie ustawione na średnią datę 2021-01-31
y = 0
plt.plot_date(x, y, "r|", markersize = 900)

for i in range(0,3):
    patches[i].set_facecolor('r')
    
plt.subplots_adjust(bottom=0.25)
# plt.savefig('wave2_hist.eps', format='eps')
plt.savefig("wave2_hist.pdf")

print(wave2_dates.min())
print(wave2_dates.max())

print(day_0_date_mean)
print(day_02_date_mean_fix)
print(mean_pandemic_day_from_date(day_02_date_mean_fix, day_0_date_mean))
# Out:
# 2021-02-04
# 2020-12-20 00:00:00
# 2021-03-01 00:00:00
# 2020-05-19
# 2021-02-04
# -261 days

# %%
wave2_dates = wave2_dates.sort_values()

#print_full(wave2_dates)
wczesniaki = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20") & (infections_fix.date < "2021-01-05"), ('date', 'district')]
#print(wczesniaki)
#print(len(wczesniaki))
późniaki = infections_fix.loc[(infections_fix.scnd_wave_day == 0) & (infections_fix.date > "2020-10-20") & (infections_fix.date > "2021-03-13"), ('date', 'district')]
#print(późniaki)

# %%
# 5935   2020-12-24              kłodzki
# 12279  2020-12-23           polkowicki
# 24987  2020-12-31  golubsko-dobrzyński
# 39115  2020-12-23          biłgorajski
# 48988  2020-12-26          tomaszowski   afsjifasijh
# 51803  2020-12-21             łukowski
# 56739  2020-12-22           nowosolski
# 71553  2020-12-31              mławski  TO WYGLĄDA CAŁKIEM OK JESZCZE RAZ POPATRZ
# 77192  2020-12-30             pułtuski   TEŻ WYGLĄDA OK
# 79298  2020-12-21         sochaczewski
# 80714  2020-12-27         szydłowiecki
# 96933  2020-12-31              olkuski
# 98333  2020-12-21          proszowicki
# 99751  2020-12-29            tarnowski
# 101152 2020-12-20           tatrzański
# 110219 2020-12-23           brzozowski
# 113649 2020-12-29          krośnieński    asdsaddasd
# 115658 2020-12-24             mielecki
# 121302 2020-12-28              sanocki
# 125829 2020-12-23          białostocki
# 128653 2020-12-27            hajnowski
# 136412 2020-12-31            łomżyński
# 190695 2020-12-29          myśliborski
# 200568 2021-01-01           opoczyński
# 230881 2020-12-30             rybnicki
# 238628 2020-12-22             żywiecki
# 243170 2021-01-01           pińczowski

which_district = "ropczycko-sędziszowski"
#which_province = "podlaskie"
fig, ax = plt.subplots()

district_cond = (infections.district == which_district)
#district_cond = (infections.district == which_district) & (infections.province == which_province)
x = infections[district_cond]["date"]
y = infections[district_cond]["new_infected_mean"] / infections[district_cond]["population"]
x2 = infections[(district_cond) & (infections.scnd_wave_day == 0) & (infections.date > "2020-10-20")]["date"]
y2 = 0
plt.plot_date(x, y, 'bo', markersize = 3)
plt.plot_date(x2, y2, "r|", markersize = 50)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Liczba zakażeń per capita (wygładzone)')
plt.ylim([0, 0.003])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.title(which_district)
# Out:
# Text(0.5, 1.0, 'ropczycko-sędziszowski')

# %%
for el in removal:
    print(el)
# Out:
# district
# province

# %%
z = infections.loc[infections.date == "2020-03-04", 'district']
print(len(z))
x = infections_fix.loc[infections_fix.date == "2020-03-04", 'district']
print(len(x))
y = infections_fix2.loc[infections_fix2.date == "2020-03-04", 'district']
print(len(y))
z = deaths.loc[deaths.date == "2020-03-04", 'district']
print(len(z))
x = deaths_fix.loc[deaths_fix.date == "2020-03-04", 'district']
print(len(x))
y = deaths_fix2.loc[deaths_fix2.date == "2020-03-04", 'district']
print(len(y))
# Out:
# 356
# 347
# 318
# 376
# 365
# 335

# %%
print_full(infections_fix2.loc[(infections_fix2.scnd_wave_day == 0) & (infections_fix2.pandemic_day < 170)])
# Out:
#              date             province                district  \
# 26435  2021-02-03   kujawsko-pomorskie             grudziądzki
# 28547  2021-01-25   kujawsko-pomorskie              mogileński
# 29969  2021-02-02   kujawsko-pomorskie            radziejowski
# 30666  2021-01-23   kujawsko-pomorskie                rypiński
# 33512  2021-02-10   kujawsko-pomorskie               tucholski
# 65228  2021-01-20          mazowieckie            ciechanowski
# 92323  2021-01-23          mazowieckie              żuromiński
# 126548 2021-01-06         podkarpackie  ropczycko-sędziszowski
# 136731 2021-01-17            podlaskie               kolneński
# 150823 2021-01-09            pomorskie                lęborski
# 163545 2021-02-10  warmińsko-mazurskie               gołdapski
# 164943 2021-01-29  warmińsko-mazurskie              kętrzyński
# 165656 2021-02-06  warmińsko-mazurskie              lidzbarski
# 167051 2021-01-22  warmińsko-mazurskie                nidzicki
# ...

# %%
#Ilość nowych przypadków per capita w czasie dla wybranego powiatu

which_district = "bieszczadzki"
# ['bieszczadzki', 'kazimierski', 'kolbuszowski', 'krosno', 'leski', 'leżajski', 'namysłowski', 'ostrołęka', 'tarnobrzeski', 'sokólski']
# which_province = "łódzkie"
fig, ax = plt.subplots()

district_cond = (infections.district == which_district)
# district_cond = (infections.district == which_district) & (infections.province == which_province)
x = infections[district_cond]["date"]
y = infections[district_cond]["new_infected_mean"] / infections[district_cond]["population"]
x2 = infections[(district_cond) & (infections.scnd_wave_day == 0) & (infections.date > "2020-10-20")]["date"]
y2 = 0
pand = infections[(district_cond) & (infections.scnd_wave_day == 0) & (infections.date > "2020-10-20")]["pandemic_day"]
#print("Data 2 fali:"+str(x2))
print(str(x2.tolist()[0]))
plt.plot_date(x, y, 'bo', markersize = 3)
plt.plot_date(x2, y2, "r|", markersize = 50)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Liczba zakażeń per capita (wygładzone)')
plt.ylim([0, 0.003])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
#ax.xaxis.set_ticklabels(ax.xaxis.get_ticklabels()+(x2.tolist()))
plt.title(which_district)
print("Dzień pandemiczny nr "+str(pand.tolist()[0]))
# Out:
# 2020-12-17 00:00:00
# Dzień pandemiczny nr 77

# %%
which_district = "giżycki"
fig, ax = plt.subplots()

x = infections[infections.district == which_district]["date"]
y = infections[infections.district == which_district]["infected_in_wave"]
plt.plot_date(x, y, 'bo', markersize = 3)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Całkowita liczba zakażonych w bieżącej fali')
#plt.ylim([0, 0.003])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.title(which_district)
# Out:
# Text(0.5, 1.0, 'giżycki')

# %%
which_district = "giżycki"
fig, ax = plt.subplots()

x = deaths[deaths.district == which_district]["date"]
y = deaths[deaths.district == which_district]["dead_in_wave"]
plt.plot_date(x, y, 'bo', markersize = 3)
plt.xlabel('Data')
#plt.xticks([])
plt.ylabel('Całkowita liczba zgonów w bieżącej fali')
#plt.ylim([0, 0.003])
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.title(which_district)
# Out:
# Text(0.5, 1.0, 'giżycki')

# %%
#Wykres wykładnika skalowania dla liczby całkowitych przypadków w zależności od kolejnych dni pandemicznych
#+ wykresy jakości dopasowania
#wykres log-log, populacja, infekcje, dane ze wszystkich powiatów

#max days_num = 695
days_num = 100
wykladniki = []
wykladniki_err = []
wartosci_R2 = []
wartosci_p = []
wartosci_S = []
wartosci_S_div = []
wartosci_S_med = []


for i in range(days_num):
    
    x = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'population']
    y = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'infected_in_wave']
    
    a, b, a_err, R2, p, S, S_div, S_med = fit_loglog_statsmodels(x, y)
    
    wykladniki.append(a)
    wykladniki_err.append(a_err)
    wartosci_R2.append(R2)
    wartosci_p.append(p)
    wartosci_S.append(S)
    wartosci_S_div.append(S_div)
    wartosci_S_med.append(S_med)

fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(21, 10))
fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0,0].plot(range(days_num), wykladniki, 'bo', markersize=3, label='a')
ax[0,0].title.set_text('Wykładnik skalowania dla zarażonych')
ax[0,0].grid(visible = True)
#ax[0,0].set_ylim([-0.1, 1.2])
ax[0,1].plot(range(days_num), wykladniki_err, 'bo', markersize=3, label='a_err')
ax[0,1].title.set_text('Odchylenie standardowe wykładnika skalowania dla zarażonych')
ax[0,1].ticklabel_format(style='plain')
ax[1,0].plot(range(days_num), wartosci_R2, 'bo', markersize=3, label='R2')
ax[1,0].title.set_text('Wartosci R2 dla zarażonych')
ax[1,0].set_ylim([0, 1])
ax[1,1].plot(range(days_num), wartosci_p, 'bo', markersize=3, label='p')
ax[1,1].title.set_text('Wartosci p dla zarażonych')
ax[1,1].set_yscale("log")
ax[2,0].plot(range(days_num), wartosci_S_div, 'bo', markersize=3, label='S_śr')
ax[2,0].title.set_text('Wartosci $S_{śr}$ dla zarażonych')
ax[2,1].plot(range(days_num), wartosci_S_med, 'bo', markersize=3, label='S_med')
ax[2,1].title.set_text('Wartosci $S_{med}$ dla zarażonych')

# ax[2,0].plot(range(days_num), wartosci_S, 'bo', markersize=3, label='S')
# ax[2,0].title.set_text('Wartosci S dla zarażonych')
# ax[2,0].set_position([0.392,0.132,0.318,0.2])
# ax[2,1].set_visible(False)
# Out:
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\MICHA~1\AppData\Local\Temp/ipykernel_9660/3058546885.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   S_div = S/y.mean()
# C:\Users\MICHA~1\AppData\Local\Temp/ipykernel_9660/3058546885.py:22: RuntimeWarning: invalid value encountered in double_scalars
#   S_med = S/y.median()
# I:\anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1666: RuntimeWarning: invalid value encountered in subtract
#   return np.sum(weights * (model.endog - mean)**2)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1666: RuntimeWarning: invalid value encountered in subtract
# ...

# %%
# %run funkcje.ipynb

# %%
#Wykres całkowitej liczby przypadków od populacji dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})


scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
y1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'infected_in_wave_mean']
x2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
y2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'infected_in_wave_mean']
x3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
y3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'infected_in_wave_mean']
x4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']
y4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'infected_in_wave_mean']


a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Populacja", "Liczba zakażeń")

plt.savefig("inf_2wave_pop_"+str(scnd_wave_day_num1)+"_days.pdf")

# %%
#Wykres całkowitej liczby śmierci od populacji dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})

scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
y1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'dead_in_wave_mean']
x2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
y2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'dead_in_wave_mean']
x3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
y3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'dead_in_wave_mean']
x4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']
y4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'dead_in_wave_mean']



a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Populacja", "Liczba zgonów")
plt.savefig("dead_2wave_pop_"+str(scnd_wave_day_num1)+"_days.pdf")

# 44?
#print_full(y1)
# print_full(y2)
# print_full(deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, ('dead_in_wave_mean', 'district')])

# %%
#Wykres całkowitej liczby przypadków od gęstości populacji dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})


scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'density_ppl_per_ha']
y1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
x2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'density_ppl_per_ha']
y2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
x3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'density_ppl_per_ha']
y3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
x4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'density_ppl_per_ha']
y4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']


a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Gęstość zaludnienia", "Liczba zakażeń per capita")

plt.savefig("inf_2wave_dens_"+str(scnd_wave_day_num1)+"_days.pdf")

# %%
#Wykres całkowitej liczby śmierci od gęstości populacji dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})

scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'density_ppl_per_ha']
y1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
x2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'density_ppl_per_ha']
y2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
x3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'density_ppl_per_ha']
y3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
x4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'density_ppl_per_ha']
y4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']


a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Gęstość zaludnienia (ha)", "Liczba zgonów per capita")

plt.savefig("dead_2wave_dens_"+str(scnd_wave_day_num1)+"_days.pdf")

# %%
#Wykres wykładnika skalowania dla liczby całkowitych przypadków w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, populacja, infekcje, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZEGO DNIA BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'population']
    y = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'infected_in_wave_mean']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'ro', markersize=3, label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_i$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'ro', markersize=3, label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("inf_2wave_pop.pdf")
# Out:
# 0.15782359687604855

# %%
#Wykres wykładnika skalowania dla liczby całkowitych zgonów w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, populacja, zgony, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZYCH 44 DNI BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'population']
    y = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'dead_in_wave_mean']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'o', markersize=3, color = 'black', label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_d$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'o', markersize=3, color = 'black', label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("dead_2wave_pop.pdf")
# Out:
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
# ...

# %%
#Wykres wykładnika skalowania dla liczby całkowitych przypadków w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, gęstość zaludnienia, infekcje, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZEGO DNIA BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'density_ppl_per_ha']
    y = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'ro', markersize=3, label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_i$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'ro', markersize=3, label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("inf_2wave_dens.pdf")
# Out:
# 0.15418726246289682

# %%
#Wykres wykładnika skalowania dla liczby całkowitych przypadków w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, gęstość zaludnienia, infekcje, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_med = []

# NIE ANALIZUJEMY PIERWSZEGO DNIA BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'density_ppl_per_ha']
    y = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_med = fit_loglog_statsmodels(x, y)
    
    wykladniki.append(a)
    wartosci_S_med.append(S_med)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax.plot(range(1, days_num), wykladniki, 'ro', markersize=3, label='a')
ax.title.set_text('Wykładnik skalowania')
ax.set_xlabel('Dni od rozpoczęcia 2. fali')
ax.set_ylabel('$\lambda_i$')
ax.grid(visible = True)
plt.subplots_adjust(bottom=0.2)

#plt.savefig("inf_2wave_dens.pdf")

# %%
# %run funkcje.ipynb

# %%
#Wykres wykładnika skalowania dla liczby całkowitych zgonów w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, gęstość, zgony, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZYCH 44 DNI BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'density_ppl_per_ha']
    y = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'o', markersize=3, color = 'black', label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_d$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'o', markersize=3, color = 'black', label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("dead_2wave_dens.pdf")
# Out:
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
# ...

# %%
#Wykres wykładnika skalowania dla liczby całkowitych zgonów w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, gęstość, zgony, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_med = []

# NIE ANALIZUJEMY PIERWSZYCH 44 DNI BO SĄ ZERA A LOG(0) = NAN
for i in range(44, days_num):
    x = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'density_ppl_per_ha']
    y = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_med = fit_loglog_statsmodels(x, y)
    
    wykladniki.append(a)
    wartosci_S_med.append(S_med)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax.plot(range(44, days_num), wykladniki, 'o', markersize=3, color = 'black', label='a')
ax.title.set_text('Wykładnik skalowania')
ax.set_xlabel('Dni od rozpoczęcia 2. fali')
ax.set_ylabel('$\lambda_d$')
ax.grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
plt.subplots_adjust(bottom=0.2)

#plt.savefig("dead_2wave_dens.pdf")

# %%
infections = infections.loc[infections.beds_10k > 1]
deaths = deaths.loc[deaths.beds_10k > 1]

# %%
infections_fix2 = infections_fix2.loc[infections_fix2.beds_10k > 1]
deaths_fix2 = deaths_fix2.loc[deaths_fix2.beds_10k > 1]
pop_area_dens = pop_area_dens.loc[pop_area_dens.beds_10k > 1]

# %%
# %run funkcje.ipynb

# %%
#Wykres całkowitej liczby przypadków per capita od łóżek dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})


scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'beds_10k']
y1 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
x2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'beds_10k']
y2 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
x3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'beds_10k']
y3 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
x4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'beds_10k']
y4 = infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']


a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Liczba łóżek na 10tys. mieszkańców", "Liczba zakażeń per capita")

#plt.savefig("inf_2wave_beds_"+str(scnd_wave_day_num1)+"_days.pdf")

# %%
#Wykres całkowitej liczby śmierci od gęstości populacji dla wybranego dnia pandemii razem z dopasowaniem
#skala log-log
#2 fala

plt.rcParams["figure.figsize"] = (16,11.5)
#plt.rcParams["figure.figsize"] = (18,12)
plt.rcParams.update({'font.size': 23})

scnd_wave_day_num1 = 50
scnd_wave_day_num2 = 100
scnd_wave_day_num3 = 150
scnd_wave_day_num4 = 200

x1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'beds_10k']
y1 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num1, 'population']
x2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'beds_10k']
y2 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num2, 'population']
x3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'beds_10k']
y3 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num3, 'population']
x4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'beds_10k']
y4 = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == scnd_wave_day_num4, 'population']


a, b, a_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels_x4_nans_fix_new(x1, y1, x2, y2, x3, y3, x4, y4, "a) "+str(scnd_wave_day_num1)+". dzień 2. fali", "b) "+str(scnd_wave_day_num2)+". dzień 2. fali", "c) "+str(scnd_wave_day_num3)+". dzień 2. fali", "d) "+str(scnd_wave_day_num4)+". dzień 2. fali", "Liczba łóżek na 10tys. mieszkańców", "Liczba zgonów per capita")

#plt.savefig("dead_2wave_beds_"+str(scnd_wave_day_num1)+"_days.pdf")

# %%
#Wykres wykładnika skalowania dla liczby całkowitych przypadków per capita w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, łózka, infekcje, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZEGO DNIA BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'beds_10k']
    y = infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'infected_in_wave_mean'] / infections_fix2.loc[infections_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'ro', markersize=3, label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_i$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'ro', markersize=3, label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("inf_2wave_beds.pdf")
# Out:
# 0.16512588865877206

# %%
#Wykres wykładnika skalowania dla liczby całkowitych zgonów w zależności od kolejnych dni 2. fali
#+ wykresy jakości dopasowania
#wykres log-log, gęstość, zgony, dane ze wszystkich powiatów

plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 23})

days_num = 200

wykladniki = []
wartosci_S_log = []

# NIE ANALIZUJEMY PIERWSZYCH 44 DNI BO SĄ ZERA A LOG(0) = NAN
for i in range(1, days_num):
    x = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'beds_10k']
    y = deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'dead_in_wave_mean'] / deaths_fix2.loc[deaths_fix2['scnd_wave_day'] == i, 'population']
    
    a, b, a_err, R2, p, S, S_div, S_log = fit_loglog_statsmodels_nans_fix_new(x, y)
    
    wykladniki.append(a)
    wartosci_S_log.append(S_log)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(18, 4))
#fig.subplots_adjust(left=0.2, hspace = 0.4)
ax[0].plot(range(1, days_num), wykladniki, 'o', markersize=3, color = 'black', label='a')
ax[0].title.set_text('Wykładnik skalowania')
ax[0].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[0].set_ylabel('$\lambda_d$')
ax[0].grid(visible = True)
#ax[0].set_ylim([-0.1, 1.2])
ax[1].plot(range(1, days_num), wartosci_S_log, 'o', markersize=3, color = 'black', label='S_log')
ax[1].title.set_text('Wartości $S_{log}$')
ax[1].set_xlabel('Dni od rozpoczęcia 2. fali')
ax[1].set_ylabel('$S_{log}$')
ax[1].grid(visible = True)
plt.subplots_adjust(bottom=0.2)

print(np.mean(wartosci_S_log))
#plt.savefig("dead_2wave_beds.pdf")
# Out:
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# I:\anaconda\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
# ...

# %%
# %run funkcje.ipynb
