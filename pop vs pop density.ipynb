# %%
# %%time

# %run dataframes.ipynb
# Out:
#      beds_10k        district            province
# 0       21.25   bolesławiecki        dolnośląskie
# 1       20.27  dzierżoniowski        dolnośląskie
# 2       22.17       głogowski        dolnośląskie
# 3       26.49        górowski        dolnośląskie
# 4       16.22        jaworski        dolnośląskie
# ..        ...             ...                 ...
# 357     62.56         wałecki  zachodniopomorskie
# 358      6.61         łobeski  zachodniopomorskie
# 359     69.43        koszalin  zachodniopomorskie
# 360     87.46        szczecin  zachodniopomorskie
# 361     28.10     świnoujście  zachodniopomorskie
#
# [362 rows x 3 columns]
#      area_ha  population  density_ppl_per_ha        district  \
# 0     130351       90103            0.691234   bolesławiecki
# 1      47851      100813            2.106811  dzierżoniowski
# 2      44327       89102            2.010107       głogowski
# 3      73827       34870            0.472320        górowski
# 4      58155       50116            0.861766        jaworski
# ..       ...         ...                 ...             ...
# 375   109306       46724            0.427461      świdwiński
# 376   141498       53039            0.374839         wałecki
# 377     9834      107048           10.885499        koszalin
# 378    30060      401907           13.370160        szczecin
# 379    20207       40888            2.023457     świnoujście
#
#                province
# 0          dolnośląskie
# 1          dolnośląskie
# 2          dolnośląskie
# 3          dolnośląskie
# 4          dolnośląskie
# ..                  ...
# 375  zachodniopomorskie
# 376  zachodniopomorskie
# 377  zachodniopomorskie
# 378  zachodniopomorskie
# 379  zachodniopomorskie
#
# [380 rows x 5 columns]
#            date      province       district  infected_total  population  \
# 4230 2020-03-04  dolnośląskie  jeleniogórski             0.0       63591
# 4231 2020-03-05  dolnośląskie  jeleniogórski             0.0       63591
# 4232 2020-03-06  dolnośląskie  jeleniogórski             0.0       63591
# 4233 2020-03-07  dolnośląskie  jeleniogórski             0.0       63591
# 4234 2020-03-08  dolnośląskie  jeleniogórski             0.0       63591
# ...         ...           ...            ...             ...         ...
# 4930 2022-02-02  dolnośląskie  jeleniogórski          6222.0       63591
# 4931 2022-02-03  dolnośląskie  jeleniogórski          6312.0       63591
# 4932 2022-02-04  dolnośląskie  jeleniogórski          6372.0       63591
# 4933 2022-02-05  dolnośląskie  jeleniogórski          6420.0       63591
# 4934 2022-02-06  dolnośląskie  jeleniogórski          6467.0       63591
#
#       area_ha  density_ppl_per_ha  new_infected  beds_10k  pandemic_day  \
# 4230    62714            1.013984           NaN       NaN           -33
# 4231    62714            1.013984           0.0       NaN           -32
# 4232    62714            1.013984           0.0       NaN           -31
# 4233    62714            1.013984           0.0       NaN           -30
# 4234    62714            1.013984           0.0       NaN           -29
# ...       ...                 ...           ...       ...           ...
# 4930    62714            1.013984          85.0       NaN           667
# 4931    62714            1.013984          90.0       NaN           668
# 4932    62714            1.013984          60.0       NaN           669
# 4933    62714            1.013984          48.0       NaN           670
# 4934    62714            1.013984          47.0       NaN           671
#
#       infected_mean  new_infected_mean  infected_in_wave  \
# 4230            NaN                NaN               0.0
# 4231            NaN                NaN               0.0
# 4232            NaN                NaN               0.0
# 4233       0.000000                NaN               0.0
# 4234       0.000000                NaN               0.0
# ...             ...                ...               ...
# 4930    6228.714286                NaN            4260.0
# 4931    6287.857143                NaN            4350.0
# 4932            NaN                NaN            4410.0
# 4933            NaN                NaN            4458.0
# 4934            NaN                NaN            4505.0
#
#       infected_in_wave_mean  2nd_wave_day  new_infected_mean_per_capita
# 4230               0.000000           NaN                           NaN
# 4231               0.000000           NaN                           NaN
# 4232               0.000000           NaN                           NaN
# 4233               0.000000           NaN                           NaN
# 4234               0.000000           NaN                           NaN
# ...                     ...           ...                           ...
# 4930            5913.714286           NaN                           NaN
# 4931            5972.857143           NaN                           NaN
# 4932                    NaN           NaN                           NaN
# 4933                    NaN           NaN                           NaN
# 4934                    NaN           NaN                           NaN
#
# [705 rows x 16 columns]
# Wall time: 5min 7s

# %%
# %run funkcje.ipynb

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 15})

# %%
slope, intercept, slope_err, R2, p, S, S_div, S_med = fit_n_plot_linlin_statsmodels(pop_area_dens.population, pop_area_dens.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich powiatów", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("slope = "+str(slope))
print("intercept = "+str(intercept))
print("slope_err = "+str(slope_err))
print("R^2 = "+str(R2))
print("p = "+str(p))
print("S = "+str(S))
print("S_div = "+str(S_div))
print("S_med = "+str(S_med))
# Out:
# slope = 3.103390836559843e-05
# intercept = 0
# slope_err = 1.8673073973534077e-06
# R^2 = 0.4215605744978399
# p = 5.574720361718256e-47
# S = 5.701973404219269
# S_div = 1.5483000254204249
# S_med = 6.287636913271339

# %%
slope, intercept, slope_err, R2, p, S, S_div, S_med = fit_n_plot_linlin_statsmodels(pop_area_dens_cities.population, pop_area_dens_cities.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich miast na prawach powiatu", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("slope = "+str(slope))
print("intercept = "+str(intercept))
print("slope_err = "+str(slope_err))
print("R^2 = "+str(R2))
print("p = "+str(p))
print("S = "+str(S))
print("S_div = "+str(S_div))
print("S_med = "+str(S_med))
# Out:
# slope = 3.9111088635057565e-05
# intercept = 0
# slope_err = 5.007623871493447e-06
# R^2 = 0.4841307633445433
# p = 6.341764696422733e-11
# S = 12.84394169639069
# S_div = 0.7835184345214726
# S_med = 0.827189279660108

# %%
# ze stałą y=ax+b, bez sensu
slope, intercept, slope_err, R2, p, S, S_div, S_med = fit_n_plot_linlin_statsmodels_intercept(pop_area_dens.population, pop_area_dens.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich powiatów", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("slope = "+str(slope))
print("intercept = "+str(intercept))
print("slope_err = "+str(slope_err))
print("R^2 = "+str(R2))
print("p = "+str(p))
print("S = "+str(S))
print("S_div = "+str(S_div))
print("S_med = "+str(S_med))
# Out:
# slope = 2.7172038827395157e-05
# intercept = 0.938171464027776
# slope_err = 2.426784088615456e-06
# R^2 = 0.24905639553002423
# p = 2.5186138345874586e-25
# S = 5.664060687340535
# S_div = 1.5380052982539205
# S_med = 6.245830089347407

# %%
lmbda, B, lmbda_err, R2, p, S, S_div, S_med = fit_n_plot_loglog_statsmodels(pop_area_dens.population, pop_area_dens.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich powiatów", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("lambda = "+str(lmbda))
print("B = "+str(B))
print("lambda_err = "+str(lmbda_err))
print("R^2 = "+str(R2))
print("p = "+str(p))
print("S = "+str(S))
print("S_div = "+str(S_div))
print("S_med = "+str(S_med))
# Out:
# lambda = 1.205355677062176
# B = -5.776240704877751
# lambda_err = 0.08872700974091641
# R^2 = 0.3280621112540578
# p = 1.651293416669659e-34
# S = 6.042595536050861
# S_div = 1.6407917327621964
# S_med = 6.663245169878901

# %%
lmbda, B, lmbda_err, R2_lin, R2_log, S_lin, S_log, S_lin_div, S_log_div, S_lin_med, S_log_med = fit_n_plot_lin_n_log_statsmodels(pop_area_dens_noncities.population, pop_area_dens_noncities.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich powiatów - nie miast", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("lambda = "+str(lmbda))
print("B = "+str(B))
print("lambda_err = "+str(lmbda_err))
print("R^2_lin = "+str(R2_lin))
print("R^2_log = "+str(R2_log))
print("S_lin = "+str(S_lin))
print("S_log = "+str(S_log))
print("S_lin_div = "+str(S_lin_div))
print("S_log_div = "+str(S_log_div))
print("S_lin_med = "+str(S_lin_med))
print("S_log_med = "+str(S_log_med))
# Out:
# lambda = 0.818590908805602
# B = -4.061920238991257
# lambda_err = 0.05274078833530941
# R^2_lin = 0.7253279201276215
# R^2_log = 0.43570481004115424
# S_lin = 0.673293482910575
# S_log = 0.6723440074392447
# S_lin_div = 0.6658225914035342
# S_log_div = 0.6648836513501382
# S_lin_med = 0.8614997328030413
# S_log_med = 0.8602848497162214

# %%
lmbda, B, lmbda_err, R2_lin, R2_log, S_lin, S_log, S_lin_div, S_log_div, S_lin_med, S_log_med = fit_n_plot_lin_n_log_statsmodels(pop_area_dens_cities.population, pop_area_dens_cities.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich miast na prawach powiatu", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("lambda = "+str(lmbda))
print("B = "+str(B))
print("lambda_err = "+str(lmbda_err))
print("R^2_lin = "+str(R2_lin))
print("R^2_log = "+str(R2_log))
print("S_lin = "+str(S_lin))
print("S_log = "+str(S_log))
print("S_lin_div = "+str(S_lin_div))
print("S_log_div = "+str(S_log_div))
print("S_lin_med = "+str(S_lin_med))
print("S_log_med = "+str(S_log_med))
# Out:
# lambda = 0.24723532350223107
# B = -0.09136785325247354
# lambda_err = 0.06996895988396647
# R^2_lin = 0.4841307633445433
# R^2_log = 0.16324143283174197
# S_lin = 12.84394169639069
# S_log = 6.3827578929188835
# S_lin_div = 0.7835184345214726
# S_log_div = 0.3893671110010351
# S_lin_med = 0.827189279660108
# S_log_med = 0.41106920511575634

# %%
lmbda, B, lmbda_err, R2_lin, R2_log, S_lin, S_log, S_lin_div, S_log_div, S_lin_med, S_log_med = fit_n_plot_lin_n_log_statsmodels(pop_area_dens.population, pop_area_dens.density_ppl_per_ha,
                              "Zależność gęstości populacji od populacji dla polskich powiatów", 
                              "Populacja", "Gęstość populacji (1/ha)")
print("lambda = "+str(lmbda))
print("B = "+str(B))
print("lambda_err = "+str(lmbda_err))
print("R^2_lin = "+str(R2_lin))
print("R^2_log = "+str(R2_log))
print("S_lin = "+str(S_lin))
print("S_log = "+str(S_log))
print("S_lin_div = "+str(S_lin_div))
print("S_log_div = "+str(S_log_div))
print("S_lin_med = "+str(S_lin_med))
print("S_log_med = "+str(S_log_med))
# Out:
# lambda = 1.205355677062176
# B = -5.776240704877751
# lambda_err = 0.08872700974091641
# R^2_lin = 0.4215605744978399
# R^2_log = 0.3280621112540578
# S_lin = 5.701973404219269
# S_log = 6.042595536050861
# S_lin_div = 1.5483000254204249
# S_log_div = 1.6407917327621964
# S_lin_med = 6.287636913271339
# S_log_med = 6.663245169878901
