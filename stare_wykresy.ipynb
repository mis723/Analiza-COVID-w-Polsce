# %%
# %%time
# %run dataframes.ipynb
# Out:
# last valid idx
# 15899.0
# last valid infections
# 1222.0
#              date        province       district  dead_total  population  \
# 0      2020-03-04    dolnośląskie  bolesławiecki         0.0       90103
# 1      2020-03-05    dolnośląskie  bolesławiecki         0.0       90103
# 2      2020-03-06    dolnośląskie  bolesławiecki         0.0       90103
# 3      2020-03-07    dolnośląskie  bolesławiecki         0.0       90103
# 4      2020-03-08    dolnośląskie  bolesławiecki         0.0       90103
# ...           ...             ...            ...         ...         ...
# 272075 2022-02-13  świętokrzyskie   włoszczowski       158.0       45059
# 272076 2022-02-14  świętokrzyskie   włoszczowski       158.0       45059
# 272077 2022-02-15  świętokrzyskie   włoszczowski       158.0       45059
# 272078 2022-02-16  świętokrzyskie   włoszczowski       158.0       45059
# 272079 2022-02-17  świętokrzyskie   włoszczowski       160.0       45059
#
# ...

# %%
# %run funkcje.ipynb
plt.rcParams["figure.figsize"] = (12,8)
plt.rcParams.update({'font.size': 17})

# %%
import warnings
import matplotlib.ticker
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Ilość całkowitych przypadków w czasie dla wybranego powiatu
plt.rcParams.update({'font.size': 20})
which_district = "warszawa"
fig, ax = plt.subplots()
x = infections[infections.district == which_district]["date"]
y = infections[infections.district == which_district]["infected_total"]
plt.plot_date(x, y, 'ro', markersize = 2)

# z = deaths[deaths.district == which_district]["dead_total"]
# z.drop(z.tail(11).index, inplace = True)
# plt.plot_date(x, z)


plt.xlabel('Data')
plt.ylabel('Całkowita liczba zakażeń')
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%m.%y'))
ax.xaxis.set_minor_locator(matplotlib.dates.MonthLocator())
# albo daty pionowo:
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=90)
# albo daty wyświetlane co 3 tick
# every_nth = 3
# for n, label in enumerate(ax.xaxis.get_ticklabels()):
#     if n % every_nth != 0:
#         label.set_visible(False)
plt.title("Warszawa")
plt.subplots_adjust(bottom=0.2)

#plt.savefig('warszawa_inf.eps', format='eps')
plt.savefig("warszawa_inf.pdf")

# %%
dates = pd.date_range(start="2020-03-04", end="2022-02-06", freq="1D")
#print(dates)
sums = []
for datee in dates:
    sums.append(infections.loc[infections.date == datee]["new_infected"].sum())
    
sums_dead = []
for datee in dates:
    sums_dead.append(deaths.loc[deaths.date == datee]["new_death"].sum())
    
#print(sums)

# %%
for datee in dates:
    print(deaths.loc[deaths.date == datee]['dead_total'].isna().sum())
    print(datee)
# Out:
# 25
# 2020-03-04 00:00:00
# 25
# 2020-03-05 00:00:00
# 25
# 2020-03-06 00:00:00
# 25
# 2020-03-07 00:00:00
# 25
# 2020-03-08 00:00:00
# 25
# 2020-03-09 00:00:00
# 25
# 2020-03-10 00:00:00
# 25
# 2020-03-11 00:00:00
# 25
# 2020-03-12 00:00:00
# 25
# 2020-03-13 00:00:00
# 49
# 2020-03-14 00:00:00
# 49
# 2020-03-15 00:00:00
# 49
# 2020-03-16 00:00:00
# 49
# 2020-03-17 00:00:00
# 49
# 2020-03-18 00:00:00
# 49
# 2020-03-19 00:00:00
# 49
# 2020-03-20 00:00:00
# 49
# 2020-03-21 00:00:00
# 49
# 2020-03-22 00:00:00
# 49
# 2020-03-23 00:00:00
# 49
# 2020-03-24 00:00:00
# 49
# 2020-03-25 00:00:00
# 49
# 2020-03-26 00:00:00
# 49
# 2020-03-27 00:00:00
# 49
# 2020-03-28 00:00:00
# 49
# 2020-03-29 00:00:00
# 49
# 2020-03-30 00:00:00
# 49
# 2020-03-31 00:00:00
# 49
# 2020-04-01 00:00:00
# 49
# 2020-04-02 00:00:00
# 49
# 2020-04-03 00:00:00
# 49
# 2020-04-04 00:00:00
# 49
# 2020-04-05 00:00:00
# 49
# 2020-04-06 00:00:00
# 49
# 2020-04-07 00:00:00
# 72
# 2020-04-08 00:00:00
# 72
# 2020-04-09 00:00:00
# ...

# %%
#Ilość całkowitych przypadków w czasie dla całej Polski
plt.rcParams.update({'font.size': 20})
fig, ax = plt.subplots()
x = dates
y = sums
plt.plot_date(x, y, 'r-', markersize = 2)
x2 = pd.to_datetime("2021-02-03")
y2 = 0
#3 lutego 2021
plt.plot_date(x2, y2, "g|", markersize = 770)
plt.xlabel('Data')
plt.ylabel('Całkowita liczba zakażeń')
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%m.%y'))
ax.xaxis.set_minor_locator(matplotlib.dates.MonthLocator())
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)
# albo daty pionowo:
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=90)
# albo daty wyświetlane co 3 tick
# every_nth = 3
# for n, label in enumerate(ax.xaxis.get_ticklabels()):
#     if n % every_nth != 0:
#         label.set_visible(False)
plt.title("Polska")
plt.subplots_adjust(bottom=0.2)

plt.savefig("polska_inf.pdf")

# %%
#Ilość całkowitych zgonów w czasie dla całej Polski
plt.rcParams.update({'font.size': 20})
fig, ax = plt.subplots()
x = dates
y = sums_dead
plt.plot_date(x, y, '-', color = 'black', markersize = 2)
x2 = pd.to_datetime("2021-02-03")
y2 = 0
#3 lutego 2021
plt.plot_date(x2, y2, "g|", markersize = 770)
plt.xlabel('Data')
plt.ylabel('Całkowita liczba zgonów')
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%m.%y'))
ax.xaxis.set_minor_locator(matplotlib.dates.MonthLocator())
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True) 
formatter.set_powerlimits((-1,1)) 
ax.yaxis.set_major_formatter(formatter)
# albo daty pionowo:
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=90)
# albo daty wyświetlane co 3 tick
# every_nth = 3
# for n, label in enumerate(ax.xaxis.get_ticklabels()):
#     if n % every_nth != 0:
#         label.set_visible(False)
plt.title("Polska")
plt.subplots_adjust(bottom=0.2)

plt.savefig("polska_dead.pdf")

# %%
#Ilość całkowitych przypadków w czasie dla wybranego powiatu
plt.rcParams.update({'font.size': 20})
which_district = "warszawa"
fig, ax = plt.subplots()
x = deaths[deaths.district == which_district]["date"]
y = deaths[deaths.district == which_district]["dead_total"]
plt.plot_date(x, y, 'o', markersize = 2, color= 'black')

plt.xlabel('Data')
plt.ylabel('Całkowita liczba zgonów')
ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%m.%y'))
ax.xaxis.set_minor_locator(matplotlib.dates.MonthLocator())
# albo daty pionowo:
for label in ax.get_xticklabels(which='major'):
    label.set(rotation=90)
# albo daty wyświetlane co 3 tick
# every_nth = 3
# for n, label in enumerate(ax.xaxis.get_ticklabels()):
#     if n % every_nth != 0:
#         label.set_visible(False)
plt.title("Warszawa")
plt.subplots_adjust(bottom=0.2)

#plt.savefig('warszawa_dead.eps', format='eps')
plt.savefig("warszawa_dead.pdf")

# %%
#plt.rcParams["figure.autolayout"] = True

fig, ax = plt.subplots()
# plt.title("Łóżka w szpitalach ogólnych na 10 tys. ludności")
# beds.beds_10k.plot.hist(ax=ax, bins=15,alpha=0.7, rwidth=0.85, edgecolor='black')

N, bins, patches = ax.hist(beds.beds_10k, bins=16, alpha=0.7, rwidth=0.9, edgecolor='black')
tickies = np.linspace(start = bins[0], stop = bins[-1], num = 17)
# labelies = np.linspace(start = 0, stop = 160, num = 17)
ax.set_xticks(tickies)
# ax.set_xticklabels(labelies)
ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.0f'))
ax.set_ylabel("Liczba powiatów w przedziale")
ax.set_xlabel("Liczba łóżek/10 tys. ludności")

every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)

#plt.savefig('beds_hist.eps', format='eps')
plt.savefig("beds_hist.pdf")



plt.show()

# %%
fig, ax = plt.subplots()
# plt.title("Gęstość populacji")
N, bins, patches = ax.hist(pop_area_dens.density_ppl_per_ha, bins=15, alpha=0.7, rwidth=0.9, edgecolor='black')
tickies = np.linspace(start = bins[0], stop = bins[-1], num = 16)
#labelies = np.linspace(start = 0, stop = 160, num = 16)
ax.set_xticks(tickies)
# ax.set_xticklabels(labelies)
ax.xaxis.set_major_formatter(matplotlib.ticker.FormatStrFormatter('%.0f'))
ax.set_yscale("log")
ax.set_ylabel("Liczba powiatów w przedziale")
ax.set_xlabel("Gęstość populacji (liczba osób/ha)")
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)

#plt.savefig('dens_hist.eps', format='eps')
plt.savefig("dens_hist.pdf")

# %%
class OOMFormatter(matplotlib.ticker.ScalarFormatter):
    def __init__(self, order=0, fformat="%1.1f", offset=True, mathText=True):
        self.oom = order
        self.fformat = fformat
        matplotlib.ticker.ScalarFormatter.__init__(self,useOffset=offset,useMathText=mathText)
    def _set_order_of_magnitude(self):
        self.orderOfMagnitude = self.oom
    def _set_format(self, vmin=None, vmax=None):
        self.format = self.fformat
        if self._useMathText:
            self.format = r'$\mathdefault{%s}$' % self.format

fig, ax = plt.subplots()
# plt.title("Populacja")
N, bins, patches = ax.hist(pop_area_dens.population, bins=15, alpha=0.7, rwidth=0.9, edgecolor='black')
tickies = np.linspace(start = bins[0], stop = bins[-1], num = 16)
print(bins)
#labelies = np.linspace(start = 20000., stop = 1900000., num = 16)
ax.set_xticks(tickies)
#ax.set_xticklabels(labelies)
ax.xaxis.set_major_formatter(OOMFormatter(6, "%1.1f"))
# ax.ticklabel_format(axis='x', style='sci', useMathText=True)
#ax.xaxis.set_major_formatter(FormatStrFormatter('%.0e'))
ax.set_yscale("log")
ax.set_ylabel("Liczba powiatów w przedziale")
ax.set_xlabel("Populacja")
every_nth = 2
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)

#plt.savefig('pop_hist.eps', format='eps')
plt.savefig("pop_hist.pdf")
# Out:
# [  19914.   137963.6  256013.2  374062.8  492112.4  610162.   728211.6
#   846261.2  964310.8 1082360.4 1200410.  1318459.6 1436509.2 1554558.8
#  1672608.4 1790658. ]

# %%
#print(pop_area_dens)
meann = pop_area_dens.area_ha.mean()
print("Średnia powierzchnia hrabstwa USA = 2824.9 km2")
print("Średnia powierzchnia powiatu Polski = "+str(meann/100)+" km2")
print(2824.9/(meann/100))
# Out:
# Średnia powierzchnia hrabstwa USA = 2824.9 km2
# Średnia powierzchnia powiatu Polski = 822.9085526315789 km2
# 3.432823721379798

# %%
print(pop_area_dens_cities.density_ppl_per_ha.mean())
print(pop_area_dens_noncities.density_ppl_per_ha.mean())
print()
print(pop_area_dens_cities.area_ha.mean())
print(pop_area_dens_noncities.area_ha.mean())

print(pop_area_dens_cities.density_ppl_per_ha.mean()/pop_area_dens_noncities.density_ppl_per_ha.mean())
print(pop_area_dens_noncities.area_ha.mean()/pop_area_dens_cities.area_ha.mean())
# Out:
# 16.392647741893935
# 1.0112205437356705
#
# 11319.439393939394
# 97208.41401273885
# 16.210754264678897
# 8.587741020530201

# %%
#Ilość nowych przypadków w czasie dla wybranego powiatu

# which_district = "warszawa"
# fig, ax = plt.subplots()
# plt.plot_date(infections[infections.district == which_district]["date"], infections[infections.district == which_district]["new_infected"])
# plt.xlabel('Data')
# #plt.xticks([])
# plt.ylabel('Liczba zakażeń')
# every_nth = 3
# for n, label in enumerate(ax.xaxis.get_ticklabels()):
#     if n % every_nth != 0:
#         label.set_visible(False)
# plt.title("Warszawa")

# %%
#Wykres liczby całkowitych przypadków per capita od gęstości populacji dla wybranej daty
plt.rcParams.update({'font.size': 25})
dateee = '2020-08-27'
x = infections.loc[infections['date'] == dateee, 'density_ppl_per_ha']
y = infections.loc[infections['date'] == dateee, 'infected_total'] / infections.loc[infections['date'] == dateee, 'population']

plt.plot(x, y, 'ro')
plt.yscale("log")
plt.xscale("log")
plt.xlabel('Gęstość zaludnienia')
plt.ylabel('Liczba zakażeń per capita')
plt.title("27.08.2020r.")
# Out:
# Text(0.5, 1.0, '27.08.2020r.')

# %%
#Wykres liczby całkowitych śmierci od populacji dla wybranej daty

# x = deaths.loc[deaths['date'] == '2020-09-01', 'population']
# y = deaths.loc[deaths['date'] == '2020-09-01', 'dead_total']

# plt.plot(x, y, 'bo')
# plt.yscale("log")
# plt.xscale("log")
# plt.xlabel('Populacja')
# plt.ylabel('Liczba śmierci')
# plt.title("01.09.2020r.")

# %%
#Wykres całkowitej liczby przypadków od populacji dla pierwszego dnia pandemii

# x = infections.loc[infections['pandemic_day'] == 0, 'population']
# y = infections.loc[infections['pandemic_day'] == 0, 'infected_total']

# plt.plot(x, y, 'bo')
# plt.xlabel('Populacja')
# plt.ylabel('Liczba zakażeń')

# %%
#Wykres całkowitej liczby przypadków per capita od gęstości populacji dla wybranego dnia pandemii

n = 100
x = infections.loc[infections['pandemic_day'] == n, 'density_ppl_per_ha']
y = infections.loc[infections['pandemic_day'] == n, 'infected_total'] / infections.loc[infections['pandemic_day'] == n, 'population']

plt.plot(x, y, 'ro')
plt.yscale("log")
plt.xscale("log")
plt.xlabel('Gęstość populacji')
plt.ylabel('Liczba zakażeń per capita')
plt.ylabel('Liczba zakażeń per capita')
plt.title(str(n)+" dni od 10 zarażonych")
# Out:
# Text(0.5, 1.0, '100 dni od 10 zarażonych')

# %%
#Wykres całkowitej liczby śmierci od populacji dla pierwszego dnia pandemii

# x = deaths.loc[deaths['pandemic_day'] == 0, 'population']
# y = deaths.loc[deaths['pandemic_day'] == 0, 'dead_total']

# plt.plot(x, y, 'bo')
# plt.xlabel('Populacja')
# plt.ylabel('Liczba zgonów')

# #tutaj widać, że przez wybrakowane dane na początku, niektóre powiaty w pierwszy dzień mają dużo zakażonych 
# #(zweryfikowałem, tak jest w danych)

# %%
# #print_full(infections.loc[infections['district'] == 'warszawa'])
# #print_full(infections.loc[infections['pandemic_day'] == 1])


# x = infections.loc[(infections['district'] == 'warszawa') & (infections['pandemic_day'] > 250) & (infections['pandemic_day'] < 300), 'date']
# y = infections.loc[(infections['district'] == 'warszawa') & (infections['pandemic_day'] > 250) & (infections['pandemic_day'] < 300) , 'new_infected']
# plt.plot(x, y)
# plt.xlabel('Dzień pandemiczny')
# plt.ylabel('Liczba nowych zarażonych')
# plt.title("Warszawa")

# %%
# x = infections.loc[(infections['district'] == 'warszawa') & (infections['date'] > '2020-11-19') & (infections['date'] < '2021-01-08'), 'date']
# y = infections.loc[(infections['district'] == 'warszawa') & (infections['date'] > '2020-11-19') & (infections['date'] < '2021-01-08') , 'new_infected']

# plt.plot(x, y)
# plt.xlabel('Data')
# plt.ylabel('Liczba nowych zarażonych')
# plt.xticks(dti)
# plt.grid(visible = True)
# plt.title("Warszawa")
